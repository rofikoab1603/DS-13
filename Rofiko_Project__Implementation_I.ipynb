# %% [markdown]
# <a href="https://colab.research.google.com/github/rofikoab1603/DS-13/blob/main/Rofiko_Project__Implementation_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baca Data

# %%
# Import library pandas
import pandas as pd

# %%
# Baca data menggunakan baca drive lalu pandas read_csv
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/student-math.csv')

# %% [markdown]
# # Eksplorasi Data

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Menggecek kolom data
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'freetime', 'goout', 'Dalc', 'absences', 'G1',
#        'G2', 'G3'],
#       dtype='object')

# %%
# Mengecek 10 data paling awal
data.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... nursery higher  internet  freetime  goout Dalc absences  G1  G2  G3
# 0  ...     yes    yes        no         3      4    1        6   5   6   6
# ...

# %%
# Mengecek 10 paling akhir
data.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... nursery higher  internet  freetime  goout Dalc absences  G1  G2  G3
# ...

# %%
# Ukuran Data ada berapa baris dan kolom, ada 395 Baris dan 29 kolom
data.shape
# Out:
# (395, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# mengecek statistika deskriptif
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#          freetime       goout        Dalc    absences          G1          G2  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.235443    3.108861    1.481013    5.708861   10.908861   10.713924
# ...

# %%
data.describe(include=['object', 'bool'])
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     395  395     395     395     395    395    395     395      395
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      349  208     307     281     354    141    217     145      273
#
#        schoolsup famsup paid activities nursery higher internet
# count        395    395  395        395     395    395      395
# unique         2      2    2          2       2      2        2
# top           no    yes   no        yes     yes    yes      yes
# freq         344    242  214        201     314    375      329

# %% [markdown]
# ## Tugas

# %% [markdown]
# ### 1. Nilai rata-rata (G3) akhir semua murid di sekolah "GP"

# %%
data["school"]
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
data["school"]=="GP"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Name: school, Length: 395, dtype: bool

# %%
data[data["school"]=="GP"]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %%
siswa_GP = data[data["school"]=="GP"]
siswa_GP['G3'].mean()
# Out:
# 10.489971346704872

# %% [markdown]
# ### 2. Nilai min dan max (G3) dari murid-murid di sekolah "MS"

# %%
siswa_MS = data[data["school"]=="MS"]
print (siswa_MS["G3"].min())
print (siswa_MS["G3"].max())
# Out:
# 0
# 19

# %% [markdown]
# ### 3. Proporsi jenis kelamin dari murid2

# %%
len(data)
# Out:
# 395

# %%
data["sex"].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
(data["sex"].value_counts()/len(data))*100
# Out:
# F    52.658228
# M    47.341772
# Name: sex, dtype: float64

# %% [markdown]
# ### 4. Rata2 Final Grade (G3) sesuai dengan study time

# %%
data.groupby("studytime")['G3'].mean()
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %% [markdown]
# ### 5. Rata-rata final grade (G3) sesuai dengan extra educational support

# %%
data.groupby("schoolsup")['G3'].mean()
# Out:
# schoolsup
# no     10.561047
# yes     9.431373
# Name: G3, dtype: float64
